# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from keras import backend as K
import tensorflow as tf
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import multiprocess

# %cd G:\My Drive
# Out:
# G:\My Drive

# %%
PATH = 'G:/My Drive/data/'
TRAIN_PATH = 'train/'

# %%
from PIL import Image, ImageOps
import os
import numpy as np
import re
import random

# %%
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128

# %%
def load_data(path, count, X, Y, filenames, index):
    cats = 0
    dogs = 0
    for i in range(index * count, (index + 1) * count):
        filename = filenames[i]
        try:
            if (filename.split('.')[0] == 'cat'):
                if (cats >= count / 2):
                    continue
                Y[i][0] = 1
                Y[i][1] = 0
                cats += 1
            else:
                if (dogs >= count / 2):
                    continue
                Y[i][0] = 0
                Y[i][1] = 1
                dogs += 1
            img = cv.imread(path + filename)
            img = cv.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))
            for x in range(len(img)):
                for y in range(len(img[0])):
                    X[i][x][y] = img[x][y]
        except Exception as e:
            print(e);
            print('ERROR: failed to load data')
            print(i)
            continue
        if cats + dogs == count:
            break

# %%
 #Load the data
DATA_SIZE = 15000
filenames = os.listdir(PATH + TRAIN_PATH)
X = np.zeros((DATA_SIZE, IMAGE_WIDTH, IMAGE_HEIGHT, 3))
Y = np.zeros((DATA_SIZE, 2))
random.shuffle(filenames)
load_data(PATH + TRAIN_PATH, DATA_SIZE, X, Y, filenames, 0)

# %% [markdown]
# # Define training and testing data

# %%
# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, Y)

print(len(x_train), len(x_test))

# Garbage collection
X = None
Y = None
# Out:
# 11250 3750

# %%
x_train = np.asarray(x_train).astype(np.uint8) / 255
y_train = np.asarray(y_train).astype(np.uint8)
x_test = np.asarray(x_test).astype(np.uint8) / 255
y_test = np.asarray(y_test).astype(np.uint8)

# %%
EPOCHS = 15

# %%
input_shape = x_train[0].shape;

# %%
print(input_shape)
plt.imshow(x_train[1])
# Out:
# (128, 128, 3)

# %%
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same", activation="relu", input_shape=input_shape))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(64,activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 128, 128, 8)       224
#
#  conv2d_25 (Conv2D)          (None, 128, 128, 16)      1168
#
#  batch_normalization_16 (Bat  (None, 128, 128, 16)     64
#  chNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 64, 64, 16)       0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 64, 64, 16)        0
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 16)        2320
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 32)        4640
#
#  batch_normalization_17 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 32, 32, 32)        0
#
#  conv2d_28 (Conv2D)          (None, 32, 32, 32)        9248
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_18 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 16, 16, 32)        0
#
#  flatten_4 (Flatten)         (None, 8192)              0
#
#  dense_8 (Dense)             (None, 64)                524352
#
#  batch_normalization_19 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 64)                0
#
#  dense_9 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 551,906
# Trainable params: 551,618
# Non-trainable params: 288
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
			optimizer='adam',
			metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_test, y_test), batch_size=64)
# Out:
# Epoch 1/15
# 176/176 [==============================] - 9s 47ms/step - loss: 0.8041 - accuracy: 0.6128 - val_loss: 0.7162 - val_accuracy: 0.5339
# Epoch 2/15
# 176/176 [==============================] - 8s 45ms/step - loss: 0.6279 - accuracy: 0.6831 - val_loss: 1.0952 - val_accuracy: 0.5541
# Epoch 3/15
# 176/176 [==============================] - 8s 44ms/step - loss: 0.5614 - accuracy: 0.7131 - val_loss: 0.7399 - val_accuracy: 0.5701
# Epoch 4/15
# 176/176 [==============================] - 8s 44ms/step - loss: 0.5188 - accuracy: 0.7407 - val_loss: 0.7258 - val_accuracy: 0.7120
# Epoch 5/15
# 176/176 [==============================] - 8s 44ms/step - loss: 0.4844 - accuracy: 0.7628 - val_loss: 0.5861 - val_accuracy: 0.7331
# Epoch 6/15
# 176/176 [==============================] - 8s 44ms/step - loss: 0.4656 - accuracy: 0.7790 - val_loss: 0.5123 - val_accuracy: 0.7371
# Epoch 7/15
# 176/176 [==============================] - 8s 44ms/step - loss: 0.4333 - accuracy: 0.8002 - val_loss: 0.4978 - val_accuracy: 0.7672
# Epoch 8/15
# 176/176 [==============================] - 8s 45ms/step - loss: 0.4298 - accuracy: 0.7977 - val_loss: 0.4750 - val_accuracy: 0.7795
# Epoch 9/15
# 176/176 [==============================] - 8s 45ms/step - loss: 0.4020 - accuracy: 0.8202 - val_loss: 0.4418 - val_accuracy: 0.7971
# Epoch 10/15
# 176/176 [==============================] - 8s 44ms/step - loss: 0.3735 - accuracy: 0.8330 - val_loss: 0.5118 - val_accuracy: 0.7709
# Epoch 11/15
# 176/176 [==============================] - 8s 44ms/step - loss: 0.3627 - accuracy: 0.8404 - val_loss: 0.6192 - val_accuracy: 0.7221
# Epoch 12/15
# 176/176 [==============================] - 8s 44ms/step - loss: 0.3431 - accuracy: 0.8526 - val_loss: 0.5793 - val_accuracy: 0.7277
# Epoch 13/15
# 176/176 [==============================] - 8s 44ms/step - loss: 0.3225 - accuracy: 0.8578 - val_loss: 0.5172 - val_accuracy: 0.7960
# Epoch 14/15
# 176/176 [==============================] - 8s 44ms/step - loss: 0.3303 - accuracy: 0.8577 - val_loss: 0.3928 - val_accuracy: 0.8264
# Epoch 15/15
# 176/176 [==============================] - 8s 45ms/step - loss: 0.2963 - accuracy: 0.8695 - val_loss: 0.3783 - val_accuracy: 0.8413

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='lower right')
plt.title('')
plt.show()

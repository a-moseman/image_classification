# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from keras import backend as K
import tensorflow as tf
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import multiprocess

# %cd G:\My Drive
# Out:
# G:\My Drive

# %%
PATH = 'G:/My Drive/data/'
TRAIN_PATH = 'train/'

# %%
from PIL import Image, ImageOps
import os
import numpy as np
import re
import random

# %%
IMAGE_HEIGHT = 148
IMAGE_WIDTH = 148

# %%
def load_data(path, count, X, Y, filenames, index):
    cats = 0
    dogs = 0
    for i in range(index * count, (index + 1) * count):
        filename = filenames[i]
        try:
            if (filename.split('.')[0] == 'cat'):
                if (cats >= count / 2):
                    continue
                Y[i][0] = 1
                Y[i][1] = 0
                cats += 1
            else:
                if (dogs >= count / 2):
                    continue
                Y[i][0] = 0
                Y[i][1] = 1
                dogs += 1
            img = cv.imread(path + filename)
            img = cv.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))

            for x in range(len(img)):
                for y in range(len(img[0])):
                    X[i][x][y] = img[x][y]
        except Exception as e:
            print(e);
            print('ERROR: failed to load data')
            print(i)
            continue
        if cats + dogs == count:
            break

# %%
 #Load the data
DATA_SIZE = 10000
filenames = os.listdir(PATH + TRAIN_PATH)
X = np.zeros((DATA_SIZE, IMAGE_WIDTH, IMAGE_HEIGHT, 3))
Y = np.zeros((DATA_SIZE, 2))
random.shuffle(filenames)
load_data(PATH + TRAIN_PATH, DATA_SIZE, X, Y, filenames, 0)

# %% [markdown]
# # Define training and testing data

# %%
# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, Y)

print(len(x_train), len(x_test))

# Garbage collection
X = None
Y = None
# Out:
# 7500 2500

# %%
x_train = np.asarray(x_train).astype(np.uint8) / 255
y_train = np.asarray(y_train).astype(np.uint8)
x_test = np.asarray(x_test).astype(np.uint8) / 255
y_test = np.asarray(y_test).astype(np.uint8)

# %%
EPOCHS = 15

# %%
input_shape = x_train[0].shape;

# %%
print(input_shape)
plt.imshow(x_train[1])
# Out:
# (148, 148, 3)

# %%
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same", activation="relu", input_shape=input_shape))
model.add(Conv2D(8, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(32,activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 148, 148, 8)       224
#
#  conv2d_7 (Conv2D)           (None, 148, 148, 8)       584
#
#  batch_normalization_4 (Batc  (None, 148, 148, 8)      32
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 74, 74, 8)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 74, 74, 8)         0
#
#  conv2d_8 (Conv2D)           (None, 74, 74, 16)        1168
#
#  conv2d_9 (Conv2D)           (None, 74, 74, 16)        2320
#
#  batch_normalization_5 (Batc  (None, 74, 74, 16)       64
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 37, 37, 16)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 37, 37, 16)        0
#
#  conv2d_10 (Conv2D)          (None, 37, 37, 32)        4640
#
#  conv2d_11 (Conv2D)          (None, 37, 37, 32)        9248
#
#  batch_normalization_6 (Batc  (None, 37, 37, 32)       128
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 18, 18, 32)        0
#
#  flatten_1 (Flatten)         (None, 10368)             0
#
#  dense_2 (Dense)             (None, 32)                331808
#
#  batch_normalization_7 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 350,410
# Trainable params: 350,234
# Non-trainable params: 176
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
			optimizer='adam',
			metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_test, y_test), batch_size=32)
# Out:
# Epoch 1/15
# 235/235 [==============================] - 8s 30ms/step - loss: 0.8285 - accuracy: 0.5924 - val_loss: 19.8065 - val_accuracy: 0.4932
# Epoch 2/15
# 235/235 [==============================] - 7s 28ms/step - loss: 0.6645 - accuracy: 0.6440 - val_loss: 8.1109 - val_accuracy: 0.4980
# Epoch 3/15
# 235/235 [==============================] - 6s 28ms/step - loss: 0.5927 - accuracy: 0.6921 - val_loss: 0.7719 - val_accuracy: 0.6612
# Epoch 4/15
# 235/235 [==============================] - 6s 28ms/step - loss: 0.5455 - accuracy: 0.7175 - val_loss: 0.7928 - val_accuracy: 0.6856
# Epoch 5/15
# 235/235 [==============================] - 6s 28ms/step - loss: 0.5129 - accuracy: 0.7452 - val_loss: 1.3051 - val_accuracy: 0.5616
# Epoch 6/15
# 235/235 [==============================] - 6s 28ms/step - loss: 0.4935 - accuracy: 0.7629 - val_loss: 0.6951 - val_accuracy: 0.6760
# Epoch 7/15
# 235/235 [==============================] - 6s 28ms/step - loss: 0.4800 - accuracy: 0.7675 - val_loss: 0.5370 - val_accuracy: 0.7448
# Epoch 8/15
# 235/235 [==============================] - 7s 28ms/step - loss: 0.4595 - accuracy: 0.7845 - val_loss: 0.5671 - val_accuracy: 0.7236
# Epoch 9/15
# 235/235 [==============================] - 7s 28ms/step - loss: 0.4460 - accuracy: 0.7913 - val_loss: 0.6247 - val_accuracy: 0.7076
# Epoch 10/15
# 235/235 [==============================] - 7s 28ms/step - loss: 0.4176 - accuracy: 0.8089 - val_loss: 0.4919 - val_accuracy: 0.7664
# Epoch 11/15
# 235/235 [==============================] - 7s 28ms/step - loss: 0.4101 - accuracy: 0.8164 - val_loss: 0.5209 - val_accuracy: 0.7484
# Epoch 12/15
# 235/235 [==============================] - 7s 28ms/step - loss: 0.4028 - accuracy: 0.8187 - val_loss: 0.4712 - val_accuracy: 0.7780
# Epoch 13/15
# 235/235 [==============================] - 6s 28ms/step - loss: 0.3929 - accuracy: 0.8263 - val_loss: 0.6585 - val_accuracy: 0.7092
# Epoch 14/15
# 235/235 [==============================] - 7s 28ms/step - loss: 0.3918 - accuracy: 0.8237 - val_loss: 0.5086 - val_accuracy: 0.7484
# Epoch 15/15
# 235/235 [==============================] - 6s 28ms/step - loss: 0.3605 - accuracy: 0.8408 - val_loss: 0.5308 - val_accuracy: 0.7448

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 15))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='lower right')
plt.title('')
plt.ylim([0, 1])
plt.show()

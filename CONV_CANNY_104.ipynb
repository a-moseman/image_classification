# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from keras import backend as K
import tensorflow as tf
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import multiprocess

# %cd G:\My Drive
# Out:
# G:\My Drive

# %%
PATH = 'G:/My Drive/data/'
TRAIN_PATH = 'train/'

# %%
from PIL import Image, ImageOps
import os
import numpy as np
import re
import random

# %%
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128

# %%
def load_data(path, count, X, Y, filenames, index):
    cats = 0
    dogs = 0
    for i in range(index * count, (index + 1) * count):
        filename = filenames[i]
        try:
            if (filename.split('.')[0] == 'cat'):
                if (cats >= count / 2):
                    continue
                Y[i][0] = 1
                Y[i][1] = 0
                cats += 1
            else:
                if (dogs >= count / 2):
                    continue
                Y[i][0] = 0
                Y[i][1] = 1
                dogs += 1
            img = cv.imread(path + filename)

            # Apply canny edge detection
            img = cv.Canny(img, 100, 200)

            img = cv.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))

            for x in range(len(img)):
                for y in range(len(img[0])):
                    X[i][x][y] = img[x][y]
        except Exception as e:
            print(e);
            print('ERROR: failed to load data')
            print(i)
            continue
        if cats + dogs == count:
            break

# %%
 #Load the data
DATA_SIZE = 15000
filenames = os.listdir(PATH + TRAIN_PATH)
X = np.zeros((DATA_SIZE, IMAGE_WIDTH, IMAGE_HEIGHT, 3))
Y = np.zeros((DATA_SIZE, 2))
random.shuffle(filenames)
load_data(PATH + TRAIN_PATH, DATA_SIZE, X, Y, filenames, 0)

# %% [markdown]
# # Define training and testing data

# %%
# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, Y)

print(len(x_train), len(x_test))

# Garbage collection
X = None
Y = None
# Out:
# 11250 3750

# %%
x_train = np.asarray(x_train).astype(np.uint8) / 255
y_train = np.asarray(y_train).astype(np.uint8)
x_test = np.asarray(x_test).astype(np.uint8) / 255
y_test = np.asarray(y_test).astype(np.uint8)

# %%
EPOCHS = 30

# %%
input_shape = x_train[0].shape;

# %%
print(input_shape)
plt.imshow(x_train[1])
# Out:
# (128, 128, 3)

# %%
model = Sequential()
model.add(Conv2D(4, (3, 3), padding="same", activation="relu", input_shape=input_shape))
model.add(Conv2D(4, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

'''
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
'''

'''
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
'''

model.add(Flatten())
model.add(Dense(16,activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 4)       112
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 4)       148
#
#  batch_normalization (BatchN  (None, 128, 128, 4)      16
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 4)        0
#  )
#
#  dropout (Dropout)           (None, 64, 64, 4)         0
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 16)                262160
#
#  batch_normalization_1 (Batc  (None, 16)               64
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_1 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 262,534
# Trainable params: 262,494
# Non-trainable params: 40
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
			optimizer='adam',
			metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_test, y_test), batch_size=16)
# Out:
# Epoch 1/30
# 704/704 [==============================] - 9s 9ms/step - loss: 0.7387 - accuracy: 0.5876 - val_loss: 0.6049 - val_accuracy: 0.6824
# Epoch 2/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.6047 - accuracy: 0.6761 - val_loss: 0.5777 - val_accuracy: 0.6968
# Epoch 3/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.5534 - accuracy: 0.7190 - val_loss: 0.5955 - val_accuracy: 0.6731
# Epoch 4/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.5315 - accuracy: 0.7389 - val_loss: 0.5652 - val_accuracy: 0.7096
# Epoch 5/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.5267 - accuracy: 0.7419 - val_loss: 0.5799 - val_accuracy: 0.7040
# Epoch 6/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.5077 - accuracy: 0.7510 - val_loss: 0.5708 - val_accuracy: 0.7099
# Epoch 7/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.5008 - accuracy: 0.7604 - val_loss: 0.5703 - val_accuracy: 0.7051
# Epoch 8/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4868 - accuracy: 0.7714 - val_loss: 0.5667 - val_accuracy: 0.7056
# Epoch 9/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4720 - accuracy: 0.7769 - val_loss: 0.5838 - val_accuracy: 0.7120
# Epoch 10/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4643 - accuracy: 0.7827 - val_loss: 0.5748 - val_accuracy: 0.7011
# Epoch 11/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4472 - accuracy: 0.7938 - val_loss: 0.5823 - val_accuracy: 0.7051
# Epoch 12/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4689 - accuracy: 0.7796 - val_loss: 0.5805 - val_accuracy: 0.7067
# Epoch 13/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4467 - accuracy: 0.7948 - val_loss: 0.5888 - val_accuracy: 0.7091
# Epoch 14/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4370 - accuracy: 0.7973 - val_loss: 0.6123 - val_accuracy: 0.6899
# Epoch 15/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4480 - accuracy: 0.7901 - val_loss: 0.6040 - val_accuracy: 0.6923
# Epoch 16/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4379 - accuracy: 0.7964 - val_loss: 0.5790 - val_accuracy: 0.7029
# Epoch 17/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4236 - accuracy: 0.8052 - val_loss: 0.5892 - val_accuracy: 0.7123
# Epoch 18/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4346 - accuracy: 0.7959 - val_loss: 0.8515 - val_accuracy: 0.6211
# Epoch 19/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4396 - accuracy: 0.7937 - val_loss: 0.5947 - val_accuracy: 0.6933
# Epoch 20/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4676 - accuracy: 0.7809 - val_loss: 0.5897 - val_accuracy: 0.6928
# Epoch 21/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4584 - accuracy: 0.7829 - val_loss: 0.5875 - val_accuracy: 0.6917
# Epoch 22/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4480 - accuracy: 0.7884 - val_loss: 0.6038 - val_accuracy: 0.7005
# Epoch 23/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4394 - accuracy: 0.7968 - val_loss: 0.5933 - val_accuracy: 0.7019
# Epoch 24/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4601 - accuracy: 0.7805 - val_loss: 0.5913 - val_accuracy: 0.7035
# Epoch 25/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4441 - accuracy: 0.7871 - val_loss: 0.5928 - val_accuracy: 0.6931
# Epoch 26/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4357 - accuracy: 0.7992 - val_loss: 0.6129 - val_accuracy: 0.6904
# Epoch 27/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4270 - accuracy: 0.8049 - val_loss: 0.5944 - val_accuracy: 0.6928
# Epoch 28/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4286 - accuracy: 0.8004 - val_loss: 0.5921 - val_accuracy: 0.7048
# Epoch 29/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4311 - accuracy: 0.8003 - val_loss: 0.6004 - val_accuracy: 0.6957
# Epoch 30/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4282 - accuracy: 0.8019 - val_loss: 0.5998 - val_accuracy: 0.6936

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 15))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='lower right')
plt.title('')
plt.ylim([0, 1])
plt.show()

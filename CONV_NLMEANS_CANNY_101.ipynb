# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from keras import backend as K
import tensorflow as tf
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import multiprocess

# %cd G:\My Drive
# Out:
# G:\My Drive

# %%
PATH = 'G:/My Drive/data/'
TRAIN_PATH = 'train/'

# %%
from PIL import Image, ImageOps
import os
import numpy as np
import re
import random

# %%
IMAGE_HEIGHT = 148
IMAGE_WIDTH = 148

# %%
def load_data(path, count, X, Y, filenames, index):
    cats = 0
    dogs = 0
    for i in range(index * count, (index + 1) * count):
        filename = filenames[i]
        try:
            if (filename.split('.')[0] == 'cat'):
                if (cats >= count / 2):
                    continue
                Y[i][0] = 1
                Y[i][1] = 0
                cats += 1
            else:
                if (dogs >= count / 2):
                    continue
                Y[i][0] = 0
                Y[i][1] = 1
                dogs += 1
            img = cv.imread(path + filename)
            img = cv.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))

            # Denoise the image
            img = cv.fastNlMeansDenoisingColored(img)

            # Apply canny edge detection
            img = cv.Canny(img, 100, 200)


            for x in range(len(img)):
                for y in range(len(img[0])):
                    X[i][x][y] = img[x][y]
        except Exception as e:
            print(e);
            print('ERROR: failed to load data')
            print(i)
            continue
        if cats + dogs == count:
            break

# %%
 #Load the data
DATA_SIZE = 10000
filenames = os.listdir(PATH + TRAIN_PATH)
X = np.zeros((DATA_SIZE, IMAGE_WIDTH, IMAGE_HEIGHT, 3))
Y = np.zeros((DATA_SIZE, 2))
random.shuffle(filenames)
load_data(PATH + TRAIN_PATH, DATA_SIZE, X, Y, filenames, 0)

# %% [markdown]
# # Define training and testing data

# %%
# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, Y)

print(len(x_train), len(x_test))

# Garbage collection
X = None
Y = None
# Out:
# 7500 2500

# %%
x_train = np.asarray(x_train).astype(np.uint8) / 255
y_train = np.asarray(y_train).astype(np.uint8)
x_test = np.asarray(x_test).astype(np.uint8) / 255
y_test = np.asarray(y_test).astype(np.uint8)

# %%
EPOCHS = 15

# %%
input_shape = x_train[0].shape;

# %%
print(input_shape)
plt.imshow(x_train[1])
# Out:
# (148, 148, 3)

# %%
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same", activation="relu", input_shape=input_shape))
model.add(Conv2D(8, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(32,activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 8)       224
#
#  conv2d_1 (Conv2D)           (None, 148, 148, 8)       584
#
#  batch_normalization (BatchN  (None, 148, 148, 8)      32
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 8)        0
#  )
#
#  dropout (Dropout)           (None, 74, 74, 8)         0
#
#  conv2d_2 (Conv2D)           (None, 74, 74, 16)        1168
#
#  conv2d_3 (Conv2D)           (None, 74, 74, 16)        2320
#
#  batch_normalization_1 (Batc  (None, 74, 74, 16)       64
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 16)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 37, 37, 16)        0
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 32)        4640
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 32)        9248
#
#  batch_normalization_2 (Batc  (None, 37, 37, 32)       128
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 18, 18, 32)        0
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 32)                331808
#
#  batch_normalization_3 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 350,410
# Trainable params: 350,234
# Non-trainable params: 176
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
			optimizer='adam',
			metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_test, y_test), batch_size=32)
# Out:
# Epoch 1/15
# 235/235 [==============================] - 11s 30ms/step - loss: 0.7425 - accuracy: 0.5989 - val_loss: 4.1450 - val_accuracy: 0.5364
# Epoch 2/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.5974 - accuracy: 0.6864 - val_loss: 2.3176 - val_accuracy: 0.6176
# Epoch 3/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.6011 - accuracy: 0.6885 - val_loss: 2.4294 - val_accuracy: 0.5600
# Epoch 4/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.5979 - accuracy: 0.6912 - val_loss: 0.6880 - val_accuracy: 0.5848
# Epoch 5/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.5564 - accuracy: 0.7203 - val_loss: 0.5557 - val_accuracy: 0.7208
# Epoch 6/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.5277 - accuracy: 0.7412 - val_loss: 0.5151 - val_accuracy: 0.7440
# Epoch 7/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.5144 - accuracy: 0.7525 - val_loss: 0.5233 - val_accuracy: 0.7356
# Epoch 8/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.4989 - accuracy: 0.7635 - val_loss: 0.5160 - val_accuracy: 0.7368
# Epoch 9/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.4961 - accuracy: 0.7659 - val_loss: 0.5117 - val_accuracy: 0.7464
# Epoch 10/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.4805 - accuracy: 0.7676 - val_loss: 0.5113 - val_accuracy: 0.7436
# Epoch 11/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.4813 - accuracy: 0.7753 - val_loss: 0.5198 - val_accuracy: 0.7376
# Epoch 12/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.4610 - accuracy: 0.7865 - val_loss: 0.5385 - val_accuracy: 0.7216
# Epoch 13/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.4703 - accuracy: 0.7780 - val_loss: 0.6599 - val_accuracy: 0.6600
# Epoch 14/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.4580 - accuracy: 0.7863 - val_loss: 0.7079 - val_accuracy: 0.6780
# Epoch 15/15
# 235/235 [==============================] - 6s 26ms/step - loss: 0.4523 - accuracy: 0.7952 - val_loss: 0.6359 - val_accuracy: 0.6740

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 15))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='lower right')
plt.title('')
plt.ylim([0, 1])
plt.show()

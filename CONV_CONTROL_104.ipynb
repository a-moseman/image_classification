# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from keras import backend as K
import tensorflow as tf
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import multiprocess

# %cd G:\My Drive
# Out:
# G:\My Drive

# %%
PATH = 'G:/My Drive/data/'
TRAIN_PATH = 'train/'

# %%
from PIL import Image, ImageOps
import os
import numpy as np
import re
import random

# %%
IMAGE_HEIGHT = 176
IMAGE_WIDTH = 176

# %%
def load_data(path, count, X, Y, filenames, index):
    cats = 0
    dogs = 0
    for i in range(index * count, (index + 1) * count):
        filename = filenames[i]
        try:
            if (filename.split('.')[0] == 'cat'):
                if (cats >= count / 2):
                    continue
                Y[i][0] = 1
                Y[i][1] = 0
                cats += 1
            else:
                if (dogs >= count / 2):
                    continue
                Y[i][0] = 0
                Y[i][1] = 1
                dogs += 1
            img = cv.imread(path + filename)
            img = cv.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))
            for x in range(len(img)):
                for y in range(len(img[0])):
                    X[i][x][y] = img[x][y]
        except Exception as e:
            print(e);
            print('ERROR: failed to load data')
            print(i)
            continue
        if cats + dogs == count:
            break

# %%
 #Load the data
DATA_SIZE = 15000
filenames = os.listdir(PATH + TRAIN_PATH)
X = np.zeros((DATA_SIZE, IMAGE_WIDTH, IMAGE_HEIGHT, 3))
Y = np.zeros((DATA_SIZE, 2))
random.shuffle(filenames)
load_data(PATH + TRAIN_PATH, DATA_SIZE, X, Y, filenames, 0)

# %% [markdown]
# # Define training and testing data

# %%
# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, Y)

print(len(x_train), len(x_test))

# Garbage collection
X = None
Y = None
# Out:
# 11250 3750

# %%
x_train = np.asarray(x_train).astype(np.uint8) / 255
y_train = np.asarray(y_train).astype(np.uint8)
x_test = np.asarray(x_test).astype(np.uint8) / 255
y_test = np.asarray(y_test).astype(np.uint8)

# %%
EPOCHS = 15

# %%
input_shape = x_train[0].shape;

# %%
print(input_shape)
plt.imshow(x_train[1])
# Out:
# (176, 176, 3)

# %%
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same", activation="relu", input_shape=input_shape))
model.add(Conv2D(8, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(32,activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 176, 176, 8)       224
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 8)       584
#
#  batch_normalization (BatchN  (None, 176, 176, 8)      32
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 88, 88, 8)        0
#  )
#
#  dropout (Dropout)           (None, 88, 88, 8)         0
#
#  conv2d_2 (Conv2D)           (None, 88, 88, 16)        1168
#
#  conv2d_3 (Conv2D)           (None, 88, 88, 16)        2320
#
#  batch_normalization_1 (Batc  (None, 88, 88, 16)       64
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 44, 44, 16)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 44, 44, 16)        0
#
#  conv2d_4 (Conv2D)           (None, 44, 44, 32)        4640
#
#  conv2d_5 (Conv2D)           (None, 44, 44, 32)        9248
#
#  batch_normalization_2 (Batc  (None, 44, 44, 32)       128
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 22, 22, 32)        0
#
#  flatten (Flatten)           (None, 15488)             0
#
#  dense (Dense)               (None, 32)                495648
#
#  batch_normalization_3 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 514,250
# Trainable params: 514,074
# Non-trainable params: 176
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
			optimizer='adam',
			metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_test, y_test), batch_size=32)
# Out:
# Epoch 1/15
# 352/352 [==============================] - 23s 48ms/step - loss: 0.7362 - accuracy: 0.6131 - val_loss: 1.4771 - val_accuracy: 0.4973
# Epoch 2/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.5973 - accuracy: 0.6808 - val_loss: 0.6269 - val_accuracy: 0.6621
# Epoch 3/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.5237 - accuracy: 0.7356 - val_loss: 0.6011 - val_accuracy: 0.6752
# Epoch 4/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.5334 - accuracy: 0.7293 - val_loss: 0.5262 - val_accuracy: 0.7424
# Epoch 5/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.4978 - accuracy: 0.7565 - val_loss: 0.5233 - val_accuracy: 0.7483
# Epoch 6/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.4665 - accuracy: 0.7758 - val_loss: 0.6081 - val_accuracy: 0.6979
# Epoch 7/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.4536 - accuracy: 0.7828 - val_loss: 0.5027 - val_accuracy: 0.7413
# Epoch 8/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.4350 - accuracy: 0.8005 - val_loss: 0.4193 - val_accuracy: 0.8043
# Epoch 9/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.5453 - accuracy: 0.7274 - val_loss: 0.5398 - val_accuracy: 0.7240
# Epoch 10/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.4977 - accuracy: 0.7604 - val_loss: 0.4960 - val_accuracy: 0.7464
# Epoch 11/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.4675 - accuracy: 0.7822 - val_loss: 0.4469 - val_accuracy: 0.7872
# Epoch 12/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.4449 - accuracy: 0.7990 - val_loss: 0.4502 - val_accuracy: 0.7923
# Epoch 13/15
# 352/352 [==============================] - 12s 35ms/step - loss: 0.4332 - accuracy: 0.8077 - val_loss: 0.4196 - val_accuracy: 0.8136
# Epoch 14/15
# 352/352 [==============================] - 12s 34ms/step - loss: 0.4197 - accuracy: 0.8146 - val_loss: 0.4241 - val_accuracy: 0.8157
# Epoch 15/15
# 352/352 [==============================] - 12s 34ms/step - loss: 0.4216 - accuracy: 0.8144 - val_loss: 0.4160 - val_accuracy: 0.8101

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='lower right')
plt.title('')
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from keras import backend as K
import tensorflow as tf
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import multiprocess

# %cd G:\My Drive
# Out:
# G:\My Drive

# %%
PATH = 'G:/My Drive/data/'
TRAIN_PATH = 'train/'

# %%
from PIL import Image, ImageOps
import os
import numpy as np
import re
import random

# %%
IMAGE_HEIGHT = 176
IMAGE_WIDTH = 176

# %%
def load_data(path, count, X, Y, filenames, index):
    cats = 0
    dogs = 0
    for i in range(index * count, (index + 1) * count):
        filename = filenames[i]
        try:
            if (filename.split('.')[0] == 'cat'):
                if (cats >= count / 2):
                    continue
                Y[i][0] = 1
                Y[i][1] = 0
                cats += 1
            else:
                if (dogs >= count / 2):
                    continue
                Y[i][0] = 0
                Y[i][1] = 1
                dogs += 1
            img = cv.imread(path + filename)
            img = cv.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))
            #Apply gaussian blur
            img = cv.GaussianBlur(img, (5,5), cv.BORDER_DEFAULT)
            for x in range(len(img)):
                for y in range(len(img[0])):
                    X[i][x][y] = img[x][y]
        except Exception as e:
            print(e);
            print('ERROR: failed to load data')
            print(i)
            continue
        if cats + dogs == count:
            break

# %%
 #Load the data
DATA_SIZE = 15000
filenames = os.listdir(PATH + TRAIN_PATH)
X = np.zeros((DATA_SIZE, IMAGE_WIDTH, IMAGE_HEIGHT, 3))
Y = np.zeros((DATA_SIZE, 2))
random.shuffle(filenames)
load_data(PATH + TRAIN_PATH, DATA_SIZE, X, Y, filenames, 0)

# %% [markdown]
# # Define training and testing data

# %%
# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, Y)

print(len(x_train), len(x_test))

# Garbage collection
X = None
Y = None
# Out:
# 11250 3750

# %%
x_train = np.asarray(x_train).astype(np.uint8) / 255
y_train = np.asarray(y_train).astype(np.uint8)
x_test = np.asarray(x_test).astype(np.uint8) / 255
y_test = np.asarray(y_test).astype(np.uint8)

# %%
EPOCHS = 15

# %%
input_shape = x_train[0].shape;

# %%
print(input_shape)
plt.imshow(x_train[1])
# Out:
# (176, 176, 3)

# %%
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same", activation="relu", input_shape=input_shape))
model.add(Conv2D(8, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(32,activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 176, 176, 8)       224
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 8)       584
#
#  batch_normalization (BatchN  (None, 176, 176, 8)      32
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 88, 88, 8)        0
#  )
#
#  dropout (Dropout)           (None, 88, 88, 8)         0
#
#  conv2d_2 (Conv2D)           (None, 88, 88, 16)        1168
#
#  conv2d_3 (Conv2D)           (None, 88, 88, 16)        2320
#
#  batch_normalization_1 (Batc  (None, 88, 88, 16)       64
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 44, 44, 16)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 44, 44, 16)        0
#
#  conv2d_4 (Conv2D)           (None, 44, 44, 32)        4640
#
#  conv2d_5 (Conv2D)           (None, 44, 44, 32)        9248
#
#  batch_normalization_2 (Batc  (None, 44, 44, 32)       128
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 22, 22, 32)        0
#
#  flatten (Flatten)           (None, 15488)             0
#
#  dense (Dense)               (None, 32)                495648
#
#  batch_normalization_3 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 514,250
# Trainable params: 514,074
# Non-trainable params: 176
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
			optimizer='adam',
			metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_test, y_test), batch_size=64)
# Out:
# Epoch 1/15
# 176/176 [==============================] - 22s 99ms/step - loss: 0.7477 - accuracy: 0.5962 - val_loss: 1.2670 - val_accuracy: 0.5029
# Epoch 2/15
# 176/176 [==============================] - 11s 61ms/step - loss: 0.6035 - accuracy: 0.6798 - val_loss: 4.3895 - val_accuracy: 0.5003
# Epoch 3/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.5546 - accuracy: 0.7178 - val_loss: 5.4163 - val_accuracy: 0.5163
# Epoch 4/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.5753 - accuracy: 0.7086 - val_loss: 0.9376 - val_accuracy: 0.6989
# Epoch 5/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.5739 - accuracy: 0.7026 - val_loss: 0.7357 - val_accuracy: 0.6813
# Epoch 6/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.4941 - accuracy: 0.7576 - val_loss: 0.6886 - val_accuracy: 0.7285
# Epoch 7/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.4643 - accuracy: 0.7805 - val_loss: 0.5592 - val_accuracy: 0.7781
# Epoch 8/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.4355 - accuracy: 0.8025 - val_loss: 0.8369 - val_accuracy: 0.7464
# Epoch 9/15
# 176/176 [==============================] - 11s 61ms/step - loss: 0.4121 - accuracy: 0.8125 - val_loss: 0.5515 - val_accuracy: 0.7891
# Epoch 10/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.3920 - accuracy: 0.8214 - val_loss: 0.6086 - val_accuracy: 0.7819
# Epoch 11/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.3682 - accuracy: 0.8372 - val_loss: 0.5046 - val_accuracy: 0.7688
# Epoch 12/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.3505 - accuracy: 0.8460 - val_loss: 0.7658 - val_accuracy: 0.7104
# Epoch 13/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.3358 - accuracy: 0.8531 - val_loss: 0.5756 - val_accuracy: 0.7413
# Epoch 14/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.3354 - accuracy: 0.8533 - val_loss: 0.5018 - val_accuracy: 0.7923
# Epoch 15/15
# 176/176 [==============================] - 11s 60ms/step - loss: 0.2968 - accuracy: 0.8740 - val_loss: 0.5105 - val_accuracy: 0.7763

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='lower right')
plt.title('')
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from keras import backend as K
import tensorflow as tf
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import multiprocess

# %cd G:\My Drive
# Out:
# G:\My Drive

# %%
PATH = 'G:/My Drive/data/'
TRAIN_PATH = 'train/'

# %%
from PIL import Image, ImageOps
import os
import numpy as np
import re
import random

# %%
IMAGE_HEIGHT = 96
IMAGE_WIDTH = 96

# %%
def load_data(path, count, X, Y, filenames, index):
    cats = 0
    dogs = 0
    for i in range(index * count, (index + 1) * count):
        filename = filenames[i]
        try:
            if (filename.split('.')[0] == 'cat'):
                if (cats >= count / 2):
                    continue
                Y[i][0] = 1
                Y[i][1] = 0
                cats += 1
            else:
                if (dogs >= count / 2):
                    continue
                Y[i][0] = 0
                Y[i][1] = 1
                dogs += 1
            img = cv.imread(path + filename)
            img = cv.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))

            #Apply canny edge detection
            img = cv.Canny(img, 100, 200)
            for x in range(len(img)):
                for y in range(len(img[0])):
                    X[i][x][y] = img[x][y]
        except Exception as e:
            print(e);
            print('ERROR: failed to load data')
            print(i)
            continue
        if cats + dogs == count:
            break

# %%
 #Load the data
DATA_SIZE = 8000
X = np.zeros((DATA_SIZE, IMAGE_WIDTH, IMAGE_HEIGHT, 3))
Y = np.zeros((DATA_SIZE, 2))
filenames = os.listdir(PATH + TRAIN_PATH)
random.shuffle(filenames)
load_data(PATH + TRAIN_PATH, DATA_SIZE, X, Y, filenames, 0)

# %% [markdown]
# # Define training and testing data

# %%
# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, Y)

print(len(x_train), len(x_test))

# Garbage collection
X = None
Y = None
# Out:
# 6000 2000

# %%
x_train = np.asarray(x_train).astype(np.uint8) / 255
y_train = np.asarray(y_train).astype(np.uint8)
x_test = np.asarray(x_test).astype(np.uint8) / 255
y_test = np.asarray(y_test).astype(np.uint8)

# %%
EPOCHS = 15

# %%
input_shape = x_train[0].shape;

# %%
print(input_shape)
plt.imshow(x_train[1])
# Out:
# (96, 96, 3)

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), padding="same", activation="relu", input_shape=input_shape))
model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(128, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(256, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(256, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256,activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_216 (Conv2D)         (None, 96, 96, 64)        1792
#
#  conv2d_217 (Conv2D)         (None, 96, 96, 64)        36928
#
#  batch_normalization_144 (Ba  (None, 96, 96, 64)       256
#  tchNormalization)
#
#  max_pooling2d_108 (MaxPooli  (None, 48, 48, 64)       0
#  ng2D)
#
#  dropout_144 (Dropout)       (None, 48, 48, 64)        0
#
#  conv2d_218 (Conv2D)         (None, 48, 48, 128)       73856
#
#  conv2d_219 (Conv2D)         (None, 48, 48, 128)       147584
#
#  batch_normalization_145 (Ba  (None, 48, 48, 128)      512
#  tchNormalization)
#
#  max_pooling2d_109 (MaxPooli  (None, 24, 24, 128)      0
#  ng2D)
#
#  dropout_145 (Dropout)       (None, 24, 24, 128)       0
#
#  conv2d_220 (Conv2D)         (None, 24, 24, 256)       295168
#
#  conv2d_221 (Conv2D)         (None, 24, 24, 256)       590080
#
#  batch_normalization_146 (Ba  (None, 24, 24, 256)      1024
#  tchNormalization)
#
#  max_pooling2d_110 (MaxPooli  (None, 12, 12, 256)      0
#  ng2D)
#
#  dropout_146 (Dropout)       (None, 12, 12, 256)       0
#
#  flatten_36 (Flatten)        (None, 36864)             0
#
#  dense_72 (Dense)            (None, 256)               9437440
#
#  batch_normalization_147 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_147 (Dropout)       (None, 256)               0
#
#  dense_73 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 10,586,178
# Trainable params: 10,584,770
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
			optimizer='adam',
			metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 188/188 [==============================] - 13s 67ms/step - loss: 0.8819 - accuracy: 0.5908 - val_loss: 2.3978 - val_accuracy: 0.5015
# Epoch 2/15
# 188/188 [==============================] - 12s 65ms/step - loss: 0.7026 - accuracy: 0.6453 - val_loss: 1.0332 - val_accuracy: 0.5015
# Epoch 3/15
# 188/188 [==============================] - 12s 65ms/step - loss: 0.5895 - accuracy: 0.6943 - val_loss: 0.5775 - val_accuracy: 0.6940
# Epoch 4/15
# 188/188 [==============================] - 12s 65ms/step - loss: 0.5417 - accuracy: 0.7368 - val_loss: 0.7571 - val_accuracy: 0.6485
# Epoch 5/15
# 188/188 [==============================] - 12s 66ms/step - loss: 0.5397 - accuracy: 0.7343 - val_loss: 0.5813 - val_accuracy: 0.6885
# Epoch 6/15
# 188/188 [==============================] - 12s 66ms/step - loss: 0.4967 - accuracy: 0.7610 - val_loss: 0.5631 - val_accuracy: 0.7390
# Epoch 7/15
# 188/188 [==============================] - 12s 66ms/step - loss: 0.4797 - accuracy: 0.7758 - val_loss: 0.5207 - val_accuracy: 0.7335
# Epoch 8/15
# 188/188 [==============================] - 12s 66ms/step - loss: 0.4523 - accuracy: 0.7903 - val_loss: 0.5511 - val_accuracy: 0.7425
# Epoch 9/15
# 188/188 [==============================] - 12s 66ms/step - loss: 0.4217 - accuracy: 0.8070 - val_loss: 0.6539 - val_accuracy: 0.7085
# Epoch 10/15
# 188/188 [==============================] - 12s 66ms/step - loss: 0.3898 - accuracy: 0.8260 - val_loss: 0.5465 - val_accuracy: 0.7375
# Epoch 11/15
# 188/188 [==============================] - 12s 66ms/step - loss: 0.3833 - accuracy: 0.8305 - val_loss: 0.5736 - val_accuracy: 0.7450
# Epoch 12/15
# 188/188 [==============================] - 13s 68ms/step - loss: 0.3618 - accuracy: 0.8442 - val_loss: 0.5684 - val_accuracy: 0.7635
# Epoch 13/15
# 188/188 [==============================] - 13s 67ms/step - loss: 0.3322 - accuracy: 0.8598 - val_loss: 0.5221 - val_accuracy: 0.7670
# Epoch 14/15
# 188/188 [==============================] - 13s 67ms/step - loss: 0.3787 - accuracy: 0.8310 - val_loss: 1.2017 - val_accuracy: 0.5250
# Epoch 15/15
# 188/188 [==============================] - 13s 67ms/step - loss: 0.3504 - accuracy: 0.8457 - val_loss: 0.5054 - val_accuracy: 0.7735

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='lower right')
plt.title('')
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
from keras import backend as K
import tensorflow as tf
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import multiprocess

# %cd G:\My Drive
# Out:
# G:\My Drive

# %%
PATH = 'G:/My Drive/data/'
TRAIN_PATH = 'train/'

# %%
from PIL import Image, ImageOps
import os
import numpy as np
import re
import random

# %%
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128

# %%
def load_data(path, count, X, Y, filenames, index):
    cats = 0
    dogs = 0
    for i in range(index * count, (index + 1) * count):
        filename = filenames[i]
        try:
            if (filename.split('.')[0] == 'cat'):
                if (cats >= count / 2):
                    continue
                Y[i][0] = 1
                Y[i][1] = 0
                cats += 1
            else:
                if (dogs >= count / 2):
                    continue
                Y[i][0] = 0
                Y[i][1] = 1
                dogs += 1
            img = cv.imread(path + filename)
            img = cv.resize(img, (IMAGE_WIDTH, IMAGE_HEIGHT))

            for x in range(len(img)):
                for y in range(len(img[0])):
                    X[i][x][y] = img[x][y]
        except Exception as e:
            print(e);
            print('ERROR: failed to load data')
            print(i)
            continue
        if cats + dogs == count:
            break

# %%
 #Load the data
DATA_SIZE = 15000
filenames = os.listdir(PATH + TRAIN_PATH)
X = np.zeros((DATA_SIZE, IMAGE_WIDTH, IMAGE_HEIGHT, 3))
Y = np.zeros((DATA_SIZE, 2))
random.shuffle(filenames)
load_data(PATH + TRAIN_PATH, DATA_SIZE, X, Y, filenames, 0)

# %% [markdown]
# # Define training and testing data

# %%
# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, Y)

print(len(x_train), len(x_test))

# Garbage collection
X = None
Y = None
# Out:
# 11250 3750

# %%
x_train = np.asarray(x_train).astype(np.uint8) / 255
y_train = np.asarray(y_train).astype(np.uint8)
x_test = np.asarray(x_test).astype(np.uint8) / 255
y_test = np.asarray(y_test).astype(np.uint8)

# %%
EPOCHS = 30

# %%
input_shape = x_train[0].shape;

# %%
print(input_shape)
plt.imshow(x_train[1])
# Out:
# (128, 128, 3)

# %%
model = Sequential()
model.add(Conv2D(4, (3, 3), padding="same", activation="relu", input_shape=input_shape))
model.add(Conv2D(4, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

'''
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
'''

'''
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
'''

model.add(Flatten())
model.add(Dense(16,activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 4)       112
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 4)       148
#
#  batch_normalization (BatchN  (None, 128, 128, 4)      16
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 4)        0
#  )
#
#  dropout (Dropout)           (None, 64, 64, 4)         0
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 16)                262160
#
#  batch_normalization_1 (Batc  (None, 16)               64
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_1 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 262,534
# Trainable params: 262,494
# Non-trainable params: 40
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
			optimizer='adam',
			metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_test, y_test), batch_size=16)
# Out:
# Epoch 1/30
# 704/704 [==============================] - 11s 9ms/step - loss: 0.7998 - accuracy: 0.5697 - val_loss: 0.6404 - val_accuracy: 0.6189
# Epoch 2/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.6397 - accuracy: 0.6384 - val_loss: 0.6308 - val_accuracy: 0.6264
# Epoch 3/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.5880 - accuracy: 0.6868 - val_loss: 0.5858 - val_accuracy: 0.6715
# Epoch 4/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.5584 - accuracy: 0.7081 - val_loss: 0.5655 - val_accuracy: 0.7008
# Epoch 5/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.5355 - accuracy: 0.7302 - val_loss: 0.5605 - val_accuracy: 0.7080
# Epoch 6/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.5071 - accuracy: 0.7498 - val_loss: 0.5476 - val_accuracy: 0.7136
# Epoch 7/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4915 - accuracy: 0.7642 - val_loss: 0.5594 - val_accuracy: 0.7088
# Epoch 8/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4758 - accuracy: 0.7733 - val_loss: 0.5583 - val_accuracy: 0.7043
# Epoch 9/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4730 - accuracy: 0.7755 - val_loss: 0.5546 - val_accuracy: 0.7192
# Epoch 10/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4556 - accuracy: 0.7895 - val_loss: 0.5623 - val_accuracy: 0.7211
# Epoch 11/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4457 - accuracy: 0.7955 - val_loss: 0.5420 - val_accuracy: 0.7259
# Epoch 12/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4348 - accuracy: 0.8022 - val_loss: 0.5724 - val_accuracy: 0.7117
# Epoch 13/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4214 - accuracy: 0.8099 - val_loss: 0.5637 - val_accuracy: 0.7117
# Epoch 14/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4107 - accuracy: 0.8162 - val_loss: 0.5764 - val_accuracy: 0.7155
# Epoch 15/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3999 - accuracy: 0.8219 - val_loss: 0.5558 - val_accuracy: 0.7272
# Epoch 16/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4081 - accuracy: 0.8185 - val_loss: 0.5658 - val_accuracy: 0.7248
# Epoch 17/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3970 - accuracy: 0.8247 - val_loss: 0.5471 - val_accuracy: 0.7307
# Epoch 18/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3872 - accuracy: 0.8291 - val_loss: 0.5741 - val_accuracy: 0.7240
# Epoch 19/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3795 - accuracy: 0.8323 - val_loss: 0.5603 - val_accuracy: 0.7275
# Epoch 20/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3741 - accuracy: 0.8354 - val_loss: 0.5768 - val_accuracy: 0.7248
# Epoch 21/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4046 - accuracy: 0.8198 - val_loss: 0.5670 - val_accuracy: 0.7163
# Epoch 22/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3671 - accuracy: 0.8363 - val_loss: 0.5740 - val_accuracy: 0.7181
# Epoch 23/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3617 - accuracy: 0.8421 - val_loss: 0.5492 - val_accuracy: 0.7301
# Epoch 24/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3585 - accuracy: 0.8464 - val_loss: 0.5562 - val_accuracy: 0.7189
# Epoch 25/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3667 - accuracy: 0.8368 - val_loss: 0.5944 - val_accuracy: 0.7155
# Epoch 26/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3507 - accuracy: 0.8483 - val_loss: 0.5571 - val_accuracy: 0.7296
# Epoch 27/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3430 - accuracy: 0.8512 - val_loss: 0.6079 - val_accuracy: 0.7120
# Epoch 28/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3448 - accuracy: 0.8485 - val_loss: 0.5632 - val_accuracy: 0.7261
# Epoch 29/30
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3443 - accuracy: 0.8502 - val_loss: 0.6078 - val_accuracy: 0.7104
# Epoch 30/30
# 704/704 [==============================] - 6s 9ms/step - loss: 0.3372 - accuracy: 0.8546 - val_loss: 0.5756 - val_accuracy: 0.7269

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 15))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='lower right')
plt.title('')
plt.ylim([0, 1])
plt.show()
